# %%
pip install geopy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="ny_restaurant")

# %%
df = pd.read_csv("DOHMH_New_York_City_Restaurant_Inspection_Results (1).csv")

# %%
df.head()
# Out:
#       CAMIS                            DBA       BORO BUILDING  \
# 0  40557912          KISMAT INDIAN CUISINE  Manhattan      603
# 1  50016943       EL NUEVO ROBLE BILLIARDS      Bronx      216
# 2  50060883         CACHAPAS Y MAS EXPRESS  Manhattan     105A
# 3  40393093  RINCON SALVADORENO RESTAURANT     Queens     9215
# 4  50018441             VIVA MIS EMPANADAS     Queens    13311
#
#                    STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 0  FORT WASHINGTON AVENUE  10040.0  2127958633              Indian
# 1        EAST  170 STREET  10456.0  3478206981             Spanish
# 2          DYCKMAN STREET  10040.0  6468526499             Spanish
# 3              149 STREET  11435.0  7185263220      Latin American
# 4           CROSSBAY BLVD  11417.0  7183227460             Mexican
#
#   INSPECTION DATE                                           ACTION  ...  \
# 0      03/05/2018  Violations were cited in the following area(s).  ...
# ...

# %%
len(df)
# Out:
# 319818

# %%
location = geolocator.geocode("2530 FREDERICK DOUGLASS BOULEVARD")

# %%
print(location.latitude)
# Out:
# 40.8162289

# %%
0 in df["STREET"].str.len()
# Out:
# True

# %%
#Note: some of the address have string length of 0 meaning we should check if the longitude/latitude data is there.
#Otherwise, remove the data point there
#Vice versa: If longitude/latitutde is missing, take the address and obtain the longitude and latitutde

# %%
#Step 1: Get the full address and see what's up

# %%
df["FULL ADDRESS"] =  df["BUILDING"] + " "  + df["STREET"]

# %%
df["BUILDING"].str.len() == 0
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 319813    False
# 319814    False
# 319815    False
# 319816    False
# 319817    False
# Name: BUILDING, Length: 319818, dtype: bool

# %%
df["BUILDING"].notnull().sum()
# Out:
# 319232

# %%
#Considering we have 319818, we only have 319232, which means we have 586 Buildings that are unaccounted for

# %%
missing_building = ~df["BUILDING"].notnull()

# %%
missing_buildings_df = df[missing_building]

# %%
pd.set_option('display.max_rows', None)
missing_buildings_df
# Out:
#            CAMIS                                                DBA  \
# 530     50006776                                CAMDEN FOOD COMPANY
# 3339    41362524                                              FRESH
# 3389    50006776                                CAMDEN FOOD COMPANY
# 4260    41362560                        CIBO EXPRESS GOURMET MARKET
# 4381    50081658                                       IRVING FARMS
# 5156    50006470                                  DYLAN'S CANDY BAR
# 5638    50017277                                         BAR VELOCE
# 5785    50002514                                        SHAKE SHACK
# 7474    50002432                                         WORLD BEAN
# 9431    50001778                                    MI CASA CANTINA
# 9458    41362561                     WORLD BEAN, VELOCITY BAR (EC2)
# 9968    41362524                                              FRESH
# 10108   50046726                                   CHIRPING CHICKEN
# ...

# %%
##Notes: Most of the missing addresses are in terminals, airports, amtrak

# %%
location = geolocator.geocode("CAMDEN FOOD COMPANY, NEW YORK")

# %%
type(print(location))
# Out:
# None
# NoneType

# %%
if(location is None):
    print("location is of the 'None' type.")
# Out:
# location is of the 'None' type.

# %%
#What we found out, some of the locations will give the none type.
# we will check if there are nones we skip else we don't
#Input latittudes and longitudes from there
# Update the csv file?
# And go through the other locations...

# %%
df["Longitude", "Latitude"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Longitude', 'Latitude')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
